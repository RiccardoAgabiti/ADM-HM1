# %%
#Say "Hello, World!" with Python

ciao="Hello, World!"
print(ciao)
# Out:
# Hello, World!

# %%
#Python If-Else
import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(raw_input().strip())
    if n%2==0:
        if n>=2 and n<=5:
            print("Not Weird")
        elif n>=6 and n<=20:
            print("Weird")
        else:
            print("Not Weird")
    else:
        print("Weird")

# %%
#Arithmetic Operators

if __name__ == '__main__':
    a = int(raw_input())
    b = int(raw_input())
    print(a+b)
    print(a-b)
    print(a*b)

# %%
#Python:Division
from __future__ import division

if __name__ == '__main__':
    a = int(raw_input())
    b = int(raw_input())

print(a//b)
print(a/b)

# %%
#Loops


if __name__ == '__main__':
    n = int(raw_input())
    for i in range (0,n):
        print(i**2)

# %%
#Write a function

def is_leap(year):
    leap = False
    if year%4==0 and year%100!=0:
        leap = True
    if year%4==0 and year%100==0 and year%400==0:
        leap = True
    
    return leap

# %%
#Print Function
from __future__ import print_function

if __name__ == '__main__':
    n = int(raw_input())

for i in range(1,n+1):
    print(i,end='')

# %%
#String Validators

if __name__ == '__main__':
    s = raw_input()
    print any(c.isalnum()  for c in s)
    print any(c.isalpha() for c in s)
    print any(c.isdigit() for c in s)
    print any(c.islower() for c in s)
    print any(c.isupper() for c in s)

# %%
#Text Alignment

#WATCHED THE DISCUSSIONS 

thickness = int(input()) #This must be an odd number
c = 'H'

#Top Cone
for i in range(thickness):
    print((c*i).rjust(thickness-1)+c+(c*i).ljust(thickness-1))

#Top Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))

#Middle Belt
for i in range((thickness+1)//2):
    print((c*thickness*5).center(thickness*6))    

#Bottom Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))    

#Bottom Cone
for i in range(thickness):
    print(((c*(thickness-i-1)).rjust(thickness)+c+(c*(thickness-i-1)).ljust(thickness)).rjust(thickness*6))

# %%
#Text Wrap
def wrap(string, max_width):
    return "\n".join(textwrap.wrap(string,max_width))

# %%
#List Comprehensions

if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    print([[a,b,c] for a in range(x+1) for b in range(y+1)for c in range(z+1) if a+b+c!=n])

# %%
#Find the Runner-Up Score!

if __name__ == '__main__':
    n = int(raw_input())
    arr = map(int, raw_input().split())
    z=max(arr)
    while max(arr)==z:
        arr.remove(max(arr))
    print(max(arr))

# %%
#Nested Lists

if __name__ == '__main__':
    StudentiEVoti=[]
    for _ in range(int(input())):
        name = input()
        score = float(input())
        StudentiEVoti.append([name,score])
    Voti=[e[1] for e in StudentiEVoti]
    Studenti=[e[0] for e in StudentiEVoti]
    Studenti=sorted(Studenti)
    VotoMinimo=min(Voti)
    Voti=[v for v in Voti if v!=VotoMinimo]
    VotoMinimo=min(Voti)
    for s in Studenti:
        if [s,VotoMinimo] in StudentiEVoti:
            print(s)

# %%
#Finding the percentage

if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    
    average=0
    for e in student_marks[query_name]:
        average+=e
    average=average/len(student_marks[query_name])
    
    print("%0.2f" % average)

# %%
#Set .add()
n=int(input())
s=set()
for i in range(n):
    string=str(input())
    s.add(string)
print(len(s))

# %%
#Tuples

if __name__ == '__main__':
    n = int(input())
    integer_list = map(int, input().split())
    t=tuple(integer_list)
    print(hash(t))

# %%
#Designer Door Mat 
#WATCHED THE DISCUSSIONS

n, m = map(int,input().split())
pattern = [('.|.'*(2*i + 1)).center(m, '-') for i in range(n//2)]
print('\n'.join(pattern + ['WELCOME'.center(m, '-')] + pattern[::-1]))

# %%
#String Split and Join

def split_and_join(line):
    # write your code here
    l=line.split(" ")
    l="-".join(l)
    return l

# %%
#What's Your Name?


def print_full_name(first, last):
    # Write your code here
    s="Hello "+first+" "+last+"! You just delved into python."
    print(s)

# %%
#Mutations

def mutate_string(string, position, character):
    l=list(string)
    l[position]=character
    string="".join(l)
    return string

# %%
#Find a string

def count_substring(string, sub_string):
    c=0
    for i in range(0,len(string)-len(sub_string)+1):
        if str(string[i:i+len(sub_string)])==sub_string:
            c+=1
    return c

# %%
#Alphabet Rangoli

#WATCHED THE DISCUSSIONS
def print_rangoli(size):
    import string
    alpha = string.ascii_lowercase
    L= []
    for i in range(n):
        s = "-".join(alpha[i:n])
        L.append((s[::-1]+s[1:]).center(4*n-3, "-"))
    print('\n'.join(L[:0:-1]+L))

# %%
#Capitalize!



# Complete the solve function below.
def solve(s):
    for x in s.split():
        s=s.replace(x,x.capitalize())
    return s

# %%
#Symmetric Difference

# Enter your code here. Read input from STDIN. Print output to STDOUT
(a,b)=(int(input()),input().split())
(c,d)=(int(input()),input().split())
x=set(b)
y=set(d)
p=y.difference(x)
q=x.difference(y)
r=p.union(q)
print('\n'.join(sorted(r, key=int)))

# %%
#Set .discard(), .remove() & .pop()

n=int(input())
s=set(map(int,input().split()))
N=int(input())

for i in range(N):
    choice=input().split()
    if choice[0]=="pop":
        s.pop()
    elif choice[0]=="remove":
        s.remove(int(choice[1]))
    elif choice[0]=="discard":
        s.discard(int(choice[1]))
print(sum(s))

# %%
#Set .union() Operation

# Enter your code here. Read input from STDIN. Print output to STDOUT
(a,b)=(int(input()),set(input().split()))
(c,d)=(int(input()),set(input().split()))
print(len(b.union(d)))

# %%
#Set .intersection() Operation

# Enter your code here. Read input from STDIN. Print output to STDOUT
a=int(input())
b=set(input().split())
c=int(input())
d=set(input().split())
print(len(b.intersection(d)))

# %%
#Set .difference() Operation

# Enter your code here. Read input from STDIN. Print output to STDOUT
a=int(input())
b=set(input().split())
c=int(input())
d=set(input().split())
print(len(b-d))

# %%
#Set .symmetric_difference() Operation

# Enter your code here. Read input from STDIN. Print output to STDOUT
a=int(input())
b=set(input().split())
c=int(input())
d=set(input().split())
print(len(b^d))

# %%
#Set Mutations

a=int(input()) 
b=set(map(int,input().split())) 
c=int(input()) 
for i in range(c):
    (cmd,_)=input().split() 
    d=set(map(int,input().split()))
    if cmd=="intersection_update":
        b=b&d
    elif cmd=="update":
        b=b|d
    elif cmd=="symmetric_difference_update":
        b=b^d
    elif cmd=="difference_update":
        b=b-d
print(sum(b))

# %%
#The Captain's Room

# Enter your code here. Read input from STDIN. Print output to STDOUT
K=int(input())
rooms=input().split()
rooms=sorted(rooms)
capt_room=(set(rooms[0::2])^set(rooms[1::2]))
print(capt_room.pop())

# %%
#Check Subset

# Enter your code here. Read input from STDIN. Print output to STDOUTDD
t=int(input()) 

for i in range(t):
    a=int(input()) 
    A=set(input().split())
    b=int(input()) 
    B=set(input().split())
    print(A.intersection(B)==A)

# %%
#Check Strict Superset


# Enter your code here. Read input from STDIN. Print output to STDOUTA=set(input().split()) 
A=set(input().split()) 
n=int(input())
 
for _ in range(n):
    if not A.issuperset(set(input().split())):
        print(False)
        break
else:
    print(True)

# %%
#collections.Counter()


# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import Counter

X=int(input()) 
S=list(map(int,input().split())) 
Scarpe=Counter(S)
N=int(input()) 
Guadagno = 0
for _ in range(N):
    (NumeroScarpe,Prezzo)=map(int,input().split())
    if Scarpe[NumeroScarpe]>0:
        Guadagno+=Prezzo
        Scarpe.subtract(Counter([NumeroScarpe]))
print(Guadagno)

# %%
#DefaultDict Tutorial


from collections import defaultdict

(n,m)=map(int,input().split(" ")) 

input1=list()

for i in range(n):
    input1.append(input())
    
input2=list()

for i in range(m):
    input2.append(input())


d=defaultdict(list)

for i in range(n):
    d[input1[i]].append(i+1)
    


for i in input2:
    if i in d:
        print(*d[i])
    else:
        print(-1)

# %%
#Collections.namedtuple()


# Enter your code here. Read input from STDIN. Print output to STDOUT5
from collections import namedtuple 

N=int(input()) 
C=input().split()

Total=0
for i in range(N):
    Students=namedtuple("Studente",C)
    (C1,C2,C3,C4)=input().split()
    Student=Students(C1,C2,C3,C4)
    Total+=int(Student.MARKS)
print("{:.2f}".format(Total/N))

# %%
#Word Order


# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import OrderedDict
n=int(input()) 
Parole= OrderedDict() 
for i in range(n):
    Parola= input().strip() 
    Parole[Parola] = Parole.get(Parola,0) + 1
print (len(Parole))
print (*Parole.values())

# %%
#Collections.deque()

# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import deque
d=deque()
n=int(input())

for i in range(n):
    c=input().split()
    if c[0]=="append":
        d.append(c[1])
    elif c[0]=="appendleft":
        d.appendleft(c[1])
    elif c[0]=="pop":
        d.pop()
    elif c[0]=="popleft":
        d.popleft()
print(*d)

# %%
#Collections.OrderedDict()


# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import OrderedDict

d=OrderedDict()
for _ in range(int(input())):
    item, space, quantity=input().rpartition(" ")
    d[item]=d.get(item,0) +int(quantity)
for item, quantity in d.items():
    print(item,quantity)

# %%
#Piling Up!

from collections import deque

for _ in range(int(input())):
    _, pila=input(),deque(map(int,input().split()))
    for c in reversed(sorted(pila)):
        if pila[-1]==c: 
            pila.pop()
        elif pila[0]==c:
            pila.popleft()
        else: 
            print("No")
            break
    else:
            print("Yes")

# %%
#Calendar Module

# Enter your code here. Read input from STDIN. Print output to STDOUT
import calendar
m,d,y=map(int,input().split())
print(list(calendar.day_name)[calendar.weekday(y,m,d)].upper())

# %%
#Time Delta

#!/bin/python3

import math
import os
import random
import re
import sys
import datetime

# Complete the time_delta function below.
def time_delta(t1, t2):
    first = datetime.datetime.strptime(t1,'%a %d %b %Y %H:%M:%S %z')
    second = datetime.datetime.strptime(t2,'%a %d %b %Y %H:%M:%S %z')
    return str(abs(int((first-second).total_seconds())))

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        t1 = input()

        t2 = input()

        delta = time_delta(t1, t2)

        fptr.write(delta + '\n')

    fptr.close()

# %%
#Exceptions

# Enter your code here. Read input from STDIN. Print output to STDOUT
for _ in range(int(input())):
    try:
        a,b=map(int,input().split())
        print(a//b)
    except ZeroDivisionError as e:
        print("Error Code:",e)
    except ValueError as e:
        print("Error Code:",e)

# %%
#Zipped!

# Enter your code here. Read input from STDIN. Print output to STDOUT
V=[]
N,X=map(int,input().split())
for _ in range(X):
    A=map(float,input().split())
    V=V+[A]
V=list(zip(*V))
for e in V:
    print(sum(e)/X)

# %%
#Athlete Sort


#!/bin/python3
N,M=map(int,input().split()) 
#N numero di atleti, M numero di attributi
j=[[int(x) for x in input().split()] for i in range(N)]
k=int(input())
j.sort(key=lambda row: row[k])
for m in j:
    print(*m)

# %%
#ginortS


# Enter your code here. Read input from STDIN. Print output to STDOUT
n=input()
l=[]
u=[]
o=[]
e=[]

for i in n:
    if i.islower():
        l.append(i)
    elif i.isupper():
        u.append(i)
    elif i.isdigit():
        if int(i)%2==0:
            e.append(i)
        else:
            o.append(i)
a=sorted(l)+sorted(u)+sorted(o)+sorted(e)
for i in a:
    print(i,end="")

# %%
#Map and Lambda Function


cube = lambda x:x**3 # complete the lambda function 

def fibonacci(n):
    if n==1:
        return([0])
    elif n==0:
        return([])
    elif n==2:
        return ([0,1])
    l=[0,1]
    for i in range(2,n):
        l.append(l[i-2]+l[i-1])
    return l
    # return a list of fibonacci numbers

# %%
#IN THE REGEX AND PARSING SECTION I WATCHED THE DISCUSSIONS NEARLY EVERY TIME

# %%
#Re.split()
regex_pattern = r"\D+"

# %%
#Group(), Groups() & Groupdict()

import re
m = re.search(r"([a-z0-9])\1+", input())
print(m.group(1) if m else -1)

# %%
#Re.findall() & Re.finditer()

# Enter your code here. Read input from STDIN. Print output to STDOUT
import re
pattern=r'(?<=[b-df-hj-np-tv-zB-DF-HJ-NP-TV-Z])([aeiouAEIOU]{2,})(?=[b-df-hj-np-tv-zB-DF-HJ-NP-TV-Z])'
a=re.findall(pattern,input())
if a==[]:
    print(-1)
else:
    for i in a:
        print(i)

# %%
#Re.start() & Re.end()

import re
S=input()
k=input()
pattern=re.compile(k)
r=pattern.search(S)
if not r: print("(-1, -1)")
while r:
    print("({0}, {1})".format(r.start(),r.end()-1))
    r = pattern.search(S,r.start() + 1)

# %%
#Regex Substitution
# Enter your code here. Read input from STDIN. Print output to STDOUT
import re
N = int(input())

for i in range(N):
      print(re.sub(r'(?<= )(&&|\|\|)(?= )', lambda x: 'and' if x.group() == '&&' else 'or', input()))

# %%
#Validating Roman Numerals

thousand = "(?:(M){0,3})?"
hundred  = "(?:(D?(C){0,3})|(CM)|(CD))?"
ten      = "(?:(L?(X){0,3})|(XC)|(XL))?"
unit     = "(?:(V?(I){0,3})|(IX)|(IV))?"

regex_pattern = r"^" + thousand + hundred + ten + unit + "$"

# %%
#Validating and Parsing Email Addresses

# Enter your code here. Read input from STDIN. Print output to STDOUT
import re
n = int(input())
for _ in range(n):
    x, y = input().split(' ')
    m = re.match(r'<[A-Za-z](\w|-|\.|_)+@[A-Za-z]+\.[A-Za-z]{1,3}>', y)
    if m:
        print(x,y)

# %%
#HTML Parser - Part 1

from html.parser import HTMLParser
class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):        
        print ('Start :',tag)
        for ele in attrs:
            print ('->',ele[0],'>',ele[1])
            
    def handle_endtag(self, tag):
        print ('End   :',tag)
        
    def handle_startendtag(self, tag, attrs):
        print ('Empty :',tag)
        for ele in attrs:
            print ('->',ele[0],'>',ele[1])
            
MyParser = MyHTMLParser()
MyParser.feed(''.join([input().strip() for _ in range(int(input()))]))

# %%
#HTML Parser - Part 2


  
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
        def handle_comment(self, data):
                if "\n" in data:
                        print(">>> Multi-line Comment  ", data, sep="\n")
                else:
                        print(">>> Single-line Comment  ", data, sep="\n")
        def handle_data(self, data):
                if data != "\n":
                        print(">>> Data", data, sep="\n")
  
  
  
  
  
  
  
  
html = ""       
for i in range(int(input())):
    html += input().rstrip()
    html += '\n'
    
parser = MyHTMLParser()
parser.feed(html)
parser.close()

# %%
#Detect HTML Tags, Attributes and Attribute Values

# Enter your code here. Read input from STDIN. Print output to STDOUT
from html.parser import HTMLParser
class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print(tag)
        [print('-> {} > {}'.format(*attr)) for attr in attrs]
        
html = '\n'.join([input() for _ in range(int(input()))])
parser = MyHTMLParser()
parser.feed(html)
parser.close()

# %%
#Validating UID

# Enter your code here. Read input from STDIN. Print output to STDOUT

import re

for _ in range(int(input())):
    u = ''.join(sorted(input()))
    try:
        assert re.search(r'[A-Z]{2}', u)
        assert re.search(r'\d\d\d', u)
        assert not re.search(r'[^a-zA-Z0-9]', u)
        assert not re.search(r'(.)\1', u)
        assert len(u) == 10
    except:
        print('Invalid')
    else:
        print('Valid')

# %%
#Validating Credit Card Numbers

# Enter your code here. Read input from STDIN. Print output to STDOUT

import re


for _ in range(int(input())):
    s = input()

    if re.match(r"^[456]([\d]{15}|[\d]{3}(-[\d]{4}){3})$", s) and not re.search(r"([\d])\1\1\1", s.replace("-", "")):
        print("Valid")
    else:
        print("Invalid")

# %%
#Validating Postal Codes
regex_integer_in_range = r"^[1-9][\d]{5}$"	# Do not delete 'r'.
regex_alternating_repetitive_digit_pair = r"(\d)(?=\d\1)"	# Do not delete 'r'.
import re
s=input()
print (bool(re.match(r'^[1-9][\d]{5}$',s) and len(re.findall(r'(\d)(?=\d\1)',s))<2 ))

# %%
#Hex Color Code

import re
pattern=r'(#[0-9a-fA-F]{3,6}){1,2}[^\n ]'
for _ in range(int(input())):
    for x in re.findall(pattern,input()):
        print(x)

# %%
#Matrix Script

#!/bin/python3

import math
import os
import random
import re
import sys

n, m = map(int, input().split())
a, b = [], ""
for _ in range(n):
    a.append(input())

for z in zip(*a):
    b += "".join(z)

print(re.sub(r"(?<=\w)([^\w]+)(?=\w)", " ", b))

# %%
#XML 1 - Find the Score



def get_attr_number(node):
    return sum(len(child.attrib) for child in node.iter())

# %%
#XML2 - Find the Maximum Depth



maxdepth = 0
def depth(elem, level):
    global maxdepth
    # your code goes here
    level += 1
    if level >= maxdepth:
        maxdepth = level
    for child in elem:
        depth(child, level)

# %%
#Standardize Mobile Number Using Decorators

def wrapper(f):
    def fun(l):
        f(map(lambda x: "+91 " + x[-10:-5] + " " + x[-5:], l))
        # complete the function
    return fun

# %%
#Decorators 2 - Name Directory



def person_lister(f):
    def inner(people):
        return map(f, sorted(people, key=lambda x: int(x[2])))          
    return inner

# %%
#Arrays



def arrays(arr):
    # complete this function
    # use numpy.array
    return numpy.array(arr, float)[::-1]

# %%
#Concatenate

import numpy as np
a, b, c = map(int,input().split())
arrA = np.array([input().split() for _ in range(a)],int)
arrB = np.array([input().split() for _ in range(b)],int)
print(np.concatenate((arrA, arrB), axis = 0))

# %%
#Zeros and Ones

import numpy
nums = tuple(map(int, input().split()))
print (numpy.zeros(nums, dtype = numpy.int))
print (numpy.ones(nums, dtype = numpy.int))

# %%
#Eye and Identity

 #WATCH THE HACKERRANK SOLUTIONS DUE TO THE BUG IN THE OUTPUT
import numpy
print(str(numpy.eye(*map(int,input().split()))).replace('1',' 1').replace('0',' 0'))

# %%
#Floor, Ceil and Rint

import numpy

numpy.set_printoptions(sign=' ')

a = numpy.array(input().split(),float)

print(numpy.floor(a))
print(numpy.ceil(a))
print(numpy.rint(a))

# %%
#Sum and Prod

import numpy
N, M = map(int, input().split())
A = numpy.array([input().split() for _ in range(N)],int)
print(numpy.prod(numpy.sum(A, axis=0), axis=0))

# %%
#Min and Max


import numpy
arr=[]
n,m=map(int,input().split())
for row in range(n):
    my_arr=list(map(int,input().split()))
    arr.append(my_arr)
my_array=numpy.array(arr)
result=numpy.min(my_array, axis = 1)
print(max(result))

# %%
#Transpose and Flatten

import numpy
n, m = map(int, input().split())
array = numpy.array([input().strip().split() for _ in range(n)], int)
print (array.transpose())
print (array.flatten())

# %%
#Mean, Var, and Std

import numpy


N, M = map(int, input().strip().split())

a = numpy.array([ input().strip().split() for _ in range(N) ], int)

print(numpy.mean(a, axis = 1))
print(numpy.var(a, axis = 0))
print(round(numpy.std(a, axis = None),11))

# %%
#Dot and Cross

import numpy

n=int(input())

v=numpy.array([list(map(int,input().split())) for _ in range(n)])

w=numpy.array([list(map(int,input().split())) for _ in range(n)])

print(numpy.dot(v,w))

# %%
#Inner and Outer

import numpy
a=numpy.array(input().split(), int)
b=numpy.array(input().split(),int)
print(numpy.inner(a,b),numpy.outer(a,b), sep="\n")

# %%
#Polynomials


import numpy
p=list(map(float,input().split()))
x=input()
print(numpy.polyval(p,int(x)))

# %%
#Linear Algebra


import numpy
n=int(input())
a=numpy.array([input().split() for _ in range(n)],float)
numpy.set_printoptions(legacy='1.13')
print(numpy.linalg.det(a))

# %%
#The Minion Game
def minion_game(string):
    vowel =['A','E','I','O','U']
    S=0
    K=0
    for i in range(len(string)):
        if string[i] in vowel:
            K+= len(string)-i
        else:
            S+=len(string)-i
    if S>K:
        print("Stuart"+" "+ "%d" % S)
    elif K>S:
        print("Kevin"+" "+'%d' % K)
    else:
        print("Draw")
if __name__ == '__main__':

# %%
#Merge The Tools
#WATCHED THE DISCUSSIONS
def merge_the_tools(string, k):
    for i in range(0, len(string), k):
        uniq = ''
        for c in string[i : i+k]:
            if (c not in uniq):
                uniq+=c
        print(uniq)
if __name__ == '__main__':

# %%
#No Idea!

n, m = input().split()

arr= input().split()

A = set(input().split())
B = set(input().split())
print(sum([(i in A) - (i in B) for i in arr ]))
